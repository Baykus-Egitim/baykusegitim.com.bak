# %%
import os

# %%
for filename in os.listdir():
    if "H─▒zl─▒-Okuma-E─şitimi-ve-Hedeflerimiz" in filename:
        os.rename(filename,filename.replace("H─▒zl─▒-Okuma-E─şitimi-ve-Hedeflerimiz","Hızlı-Okuma-Eğitimi-ve-Hedeflerimiz"))
    #print(filename)

# %%
for filename in os.listdir():
    print(filename)
# Out:
# .ipynb_checkpoints
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-1000x500.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-115x75.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-150x150.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-225x146.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-300x195.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-50x33.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-768x499.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-768x650.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-80x80.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-85x85.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz-960x650.jpg
# Bahçeşehir-öğrenci-koçu-olarak-ne-yapıyoruz.jpg
# Bah├ğe┼şehir-H─▒zl─▒-Okuma-E─şitimi-1000x500.jpg
# Bah├ğe┼şehir-H─▒zl─▒-Okuma-E─şitimi-115x75.jpg
# Bah├ğe┼şehir-H─▒zl─▒-Okuma-E─şitimi-150x150.jpg
# Bah├ğe┼şehir-H─▒zl─▒-Okuma-E─şitimi-225x146.jpg
# Bah├ğe┼şehir-H─▒zl─▒-Okuma-E─şitimi-300x195.jpg
# ...
